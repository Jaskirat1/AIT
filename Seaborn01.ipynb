# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaskirat1/AIT/blob/main/Seaborn01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
A= sns.load_dataset('tips')

# %%
A.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
A.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
A.sample()
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 41       17.46  2.54  Male     No  Sun  Dinner     2

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
A.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
A.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
A['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
A['total_bill'].unique()
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 13.81, 11.02, 17.59,
#        20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07, 26.86, 25.28,
#        14.73, 10.51, 27.2 , 22.76, 17.29, 19.44, 16.66, 10.07, 32.68,
#        15.98, 34.83, 13.03, 18.28, 24.71, 21.16, 28.97, 22.49,  5.75,
#        16.32, 22.75, 40.17, 27.28, 12.03, 12.46, 11.35, 15.38, 44.3 ,
#        22.42, 20.92, 15.36, 20.49, 25.21, 18.24, 14.31, 14.  ,  7.25,
#        38.07, 23.95, 25.71, 17.31, 29.93, 10.65, 12.43, 24.08, 11.69,
# ...

# %%
#Distribution plot

sns.set_style('darkgrid')

# %%
sns.histplot(x ='total_bill', data =A)

# %%
sns.histplot(x = 'total_bill', data = A , bins = 10)

# %%
sns.kdeplot(x = 'total_bill', data = A)

# %%
sns.kdeplot(x = 'tip', data = A)

# %%
sns.kdeplot(x = 'size', data = A)

# %%
sns.histplot(x = 'tip', data = A)

# %%
sns.histplot(x = 'sex', data = A)

# %%
sns.histplot(x = 'day', data = A)

# %%
sns.histplot(x = 'time', data = A)

# %%
A.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.histplot(x = 'smoker', data = A)

# %%
#Countplot

sns.countplot(x= 'total_bill', data = A)

# %%
sns.countplot(x='tip', data = A)

# %%
sns.countplot(x='smoker', data = A)

# %%
sns.countplot(x='sex', data = A)

# %%
sns.countplot(x = 'time', data = A)

# %%
sns.countplot(x = 'size', data = A)

# %%
#Palette in countplot 

sns.countplot(x = 'tip', data = A, palette = 'rocket')

# %%
sns.countplot(x = 'total_bill', data = A, palette = 'magma')

# %%
sns.countplot(x = 'time', data = A, palette = 'flare')

# %%
sns.countplot(x = 'sex', data = A, palette = 'crest')

# %%
sns.countplot(x = 'size', data = A, palette = 'viridis')

# %%
sns.countplot(x = 'day', data = A, palette = 'cubehelix')

# %%
#Relational plots

sns.jointplot(x = 'total_bill', y ='tip', data = A)

# %%
sns.jointplot(x = 'total_bill', y ='sex', data = A)

# %%
sns.jointplot(x = 'total_bill', y ='smoker', data = A)

# %%
sns.jointplot(x = 'total_bill', y ='day', data = A)

# %%
sns.jointplot(x = 'total_bill', y ='time', data = A)

# %%
sns.jointplot(x = 'tip', y ='sex', data = A)

# %%
#Use of kind in Relational plots

sns.jointplot(x = 'total_bill', y ='tip', data = A, kind = 'hex')

# %%
sns.jointplot(x = 'tip', y ='sex', data = A, kind = 'hist')

# %%
sns.jointplot(x = 'size', y ='tip', data = A, kind = 'kde')

# %%
#lmplot in seaborn 

sns.lmplot(x = 'total_bill',y = 'tip', data = A)

# %%
#Pair plot 

sns.pairplot(A)

# %%
#Hue with pairplot

sns.pairplot(A, hue = 'sex')

# %%
sns.pairplot(A, hue = 'tip')

# %%
sns.pairplot(A, hue = 'time')

# %%
sns.pairplot(A, hue = 'total_bill')

# %%
#Boxplot 


sns.boxplot(x ='total_bill', y= 'tip',data = A)

# %%
sns.boxplot(x = 'tip', y = 'size', data = A)

# %%
sns.boxplot(x='day', y= 'tip', data = A)

# %%
#Correlation in Seaborn

A.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(A.corr())

# %%
sns.heatmap(A.corr(), annot = True)
